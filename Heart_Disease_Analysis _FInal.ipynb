# %% [markdown]
# #  Heart Disease Analysis
#
# **Objective:**
# This notebook analyzes patient health data to identify potential risk factors associated with heart disease. It includes data preprocessing, missing value handling, statistical summaries, and potential modeling approaches.
#
# ---

# %% [markdown]
# Final project Team Members:
#
# 1. Kalyani Gutta
# 2. Tejasree Nimmagadda
# Date: 5/11/2025

# %% [markdown]
# Importing Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# **Data** Loading and Overview

# %%
disease = pd.read_csv('Heart_attack.csv')
disease.columns = disease.columns.str.replace(' ', '_')

# %%
print("Shape of the disease dataframe", disease.shape)
# Out:
# Shape of the disease dataframe (10001, 15)

# %%
print(disease.head())
# Out:
#     Age  Gender  Blood_Pressure  Cholesterol_Level Exercise_Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Diabetes        BMI Alcohol_Consumption Stress_Level  Sleep_Hours  \
# 0       No  24.991591                High       Medium     7.633228
# 1      Yes  25.221799              Medium         High     8.744034
# 2       No  29.855447                 Low          Low     4.440440
# 3       No  24.130477                 Low         High     5.249405
# 4      Yes  20.486289                 Low         High     7.030971
#
#   Sugar_Consumption  CRP_Level  Homocysteine_Level Heart_Disease_Status
# ...

# %% [markdown]
# **Dropping column**

# %%
#Dropping off the column 'Sugar_Consumption'
disease = disease.drop('Sugar_Consumption', axis = 1)

# %%
print(disease.head())
# Out:
#     Age  Gender  Blood_Pressure  Cholesterol_Level Exercise_Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Diabetes        BMI Alcohol_Consumption Stress_Level  Sleep_Hours  \
# 0       No  24.991591                High       Medium     7.633228
# 1      Yes  25.221799              Medium         High     8.744034
# 2       No  29.855447                 Low          Low     4.440440
# 3       No  24.130477                 Low         High     5.249405
# 4      Yes  20.486289                 Low         High     7.030971
#
#    CRP_Level  Homocysteine_Level Heart_Disease_Status
# ...

# %%
#Information about the dataframe
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9972 non-null   float64
#  1   Gender                9982 non-null   object
#  2   Blood_Pressure        9982 non-null   float64
#  3   Cholesterol_Level     9971 non-null   float64
#  4   Exercise_Habits       9976 non-null   object
#  5   Smoking               9976 non-null   object
#  6   Diabetes              9971 non-null   object
#  7   BMI                   9979 non-null   float64
#  8   Alcohol_Consumption   7415 non-null   object
#  9   Stress_Level          9979 non-null   object
#  10  Sleep_Hours           9976 non-null   float64
#  11  CRP_Level             9975 non-null   float64
#  12  Homocysteine_Level    9981 non-null   float64
#  13  Heart_Disease_Status  10001 non-null  object
# dtypes: float64(7), object(7)
# ...

# %% [markdown]
# **MissingValue Detection and Imputation**

# %%
disease.isna().sum()
# Out:
# Age                       29
# Gender                    19
# Blood_Pressure            19
# Cholesterol_Level         30
# Exercise_Habits           25
# Smoking                   25
# Diabetes                  30
# BMI                       22
# Alcohol_Consumption     2586
# Stress_Level              22
# Sleep_Hours               25
# CRP_Level                 26
# Homocysteine_Level        20
# Heart_Disease_Status       0
# dtype: int64

# %% [markdown]
# It is clear that every column has null values so we need to drop

# %%
disease.dropna();

# %%
# List of columns with potential missing values
cols_to_fill = [
    'Age', 'Gender', 'Blood_Pressure', 'Cholesterol_Level',
    'Exercise_Habits', 'Smoking', 'Diabetes', 'BMI',
    'Alcohol_Consumption', 'Stress_Level', 'Sleep_Hours',
    'CRP_Level', 'Homocysteine_Level'
]

# Fill missing values: use mode for categorical, median for numeric
for col in cols_to_fill:
    if disease[col].dtype == 'object':
        disease[col] = disease[col].fillna(disease[col].mode()[0])
    else:
        disease[col] = disease[col].fillna(disease[col].median())

# Final check to confirm no missing values remain
print("\nMissing values after cleaning:")
print(disease.isna().sum())
# Out:
# Missing values after cleaning:
# Age                     0
# Gender                  0
# Blood_Pressure          0
# Cholesterol_Level       0
# Exercise_Habits         0
# Smoking                 0
# Diabetes                0
# BMI                     0
# Alcohol_Consumption     0
# Stress_Level            0
# Sleep_Hours             0
# CRP_Level               0
# Homocysteine_Level      0
# Heart_Disease_Status    0
# dtype: int64

# %%
#Understaning the summary stastics
disease.describe()
# Out:
#                 Age  Blood_Pressure  Cholesterol_Level           BMI  \
# count  10001.000000    10001.000000       10001.000000  10001.000000
# mean      49.296070      149.758524         225.420258     29.076860
# std       18.166789       17.555420          43.513925      6.299973
# min       18.000000      120.000000         150.000000     18.002837
# 25%       34.000000      134.000000         187.000000     23.669412
# 50%       49.000000      150.000000         226.000000     29.076905
# 75%       65.000000      165.000000         263.000000     34.509004
# max       80.000000      180.000000         300.000000     39.996954
#
#         Sleep_Hours     CRP_Level  Homocysteine_Level
# count  10001.000000  10001.000000        10001.000000
# mean       6.991424      7.472750           12.456169
# std        1.750926      4.334733            4.318884
# min        4.000605      0.003647            5.000236
# 25%        5.456231      3.681867            8.730039
# ...

# %% [markdown]
# **Exploratory Data Analysis (EDA)**

# %%
plt.figure(figsize=(14, 12))
sns.heatmap(
    disease.corr(numeric_only=True),
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    linewidths=0.5,
    linecolor='gray',
    square=True,
    cbar_kws={"shrink": 0.8},
    annot_kws={"size": 10}
)

plt.title("Correlation Heatmap (Coolwarm Palette)", fontsize=16, fontweight="bold")
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##  K-Nearest Neighbors (KNN) Classification for Heart Disease Prediction

# %%
# Encode categorical variables
X = pd.get_dummies(disease.drop('Heart_Disease_Status', axis=1), drop_first=True)
y = disease['Heart_Disease_Status']

# Confirm no missing values
assert X.isna().sum().sum() == 0, "X still contains missing values!"

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Train the model
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

# Predict and evaluate
y_pred_knn = knn.predict(X_test)
print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print(confusion_matrix(y_test, y_pred_knn))
print(classification_report(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.7721139430284858
# [[1517  103]
#  [ 353   28]]
#               precision    recall  f1-score   support
#
#           No       0.81      0.94      0.87      1620
#          Yes       0.21      0.07      0.11       381
#
#     accuracy                           0.77      2001
#    macro avg       0.51      0.50      0.49      2001
# weighted avg       0.70      0.77      0.72      2001

# %%
dt = DecisionTreeClassifier(max_depth=5, random_state=1)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
print('Decision Tree Accuracy:', accuracy_score(y_test, y_pred_dt))
print(confusion_matrix(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.8055972013993004
# [[1611    9]
#  [ 380    1]]
#               precision    recall  f1-score   support
#
#           No       0.81      0.99      0.89      1620
#          Yes       0.10      0.00      0.01       381
#
#     accuracy                           0.81      2001
#    macro avg       0.45      0.50      0.45      2001
# weighted avg       0.67      0.81      0.72      2001

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=3, random_state=42)
dt.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %% [markdown]
# **Decision Tree Analysis**

# %%
plt.figure(figsize=(20, 10))
plot_tree(
    dt,
    feature_names=X.columns,
    class_names=['No', 'Yes'],
    filled=True,
    rounded=True,
    precision=2,
    fontsize=10,
    max_depth=3
)
plt.title('Decision Tree (Max Depth = 3)', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Feature Importance**

# %%
features = ['Homocysteine_Level', 'CRP_Level', 'BMI', 'Blood_Pressure', 'Exercise_Habits',
            'Age', 'Sleep_Hours', 'Stress_Level', 'Cholesterol_Level', 'Gender']
importances = [0.33, 0.24, 0.14, 0.08, 0.07, 0.05, 0.05, 0.05, 0.05, 0.00]


plt.figure(figsize=(10, 6))
plt.bar(features, importances)
plt.title("Top 10 Feature Importances")
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Regression Models for Predicting Heart Disease Probability from CRP and Sleep Data

# %%
# Select features and target
reg_features = ['CRP_Level', 'Sleep_Hours']
X_reg = disease[reg_features]
y_reg = disease['Heart_Disease_Status']

# Convert y to numeric if it's still in 'Yes'/'No' format
y_reg = y_reg.map({'No': 0, 'Yes': 1})

# Fill missing values in features
X_reg = X_reg.fillna(X_reg.median())

# Standardize features
X_scaled = StandardScaler().fit_transform(X_reg)

# Train-test split
X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(X_scaled, y_reg, test_size=0.2, random_state=1)

# Define models
models = {
    'LinearRegression': LinearRegression(),
    'Lasso': Lasso(alpha=0.1),
    'Ridge': Ridge(alpha=1.0)
}

# Train and evaluate
for name, model in models.items():
    model.fit(X_train_r, y_train_r)
    print(f"{name} R2 Score:", model.score(X_test_r, y_test_r))
    print(f"{name} Coefficients:", model.coef_)
# Out:
# LinearRegression R2 Score: -0.0007946741658173551
# LinearRegression Coefficients: [-0.00124269 -0.00135828]
# Lasso R2 Score: -0.0009295166523135556
# Lasso Coefficients: [-0. -0.]
# Ridge R2 Score: -0.0007946882345295503
# Ridge Coefficients: [-0.00124254 -0.00135811]
